# %% [markdown]
# # DIVP Practical 1
# ### Name: Aniket Raut
# ### Roll no: 22
# ### Batch: B2

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
img = cv2.imread('/download.jpg',1)

# %%
(h,w,d) = img.shape

# %%
print(f'Height = {h} \nWidth = {w} \nDepth = {d}')
# Out:
# Height = 148
# Width = 148
# Depth = 3

# %% [markdown]
# **Leena Black and White Image**

# %%
# Leena Black and White Image

# %%
imggry = cv2.imread('/download.jpg',0)

# %%
# Displaying Image

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=148x148>

# %%
cv2_imshow(imggry)
# Out:
# <PIL.Image.Image image mode=L size=148x148>

# %%
# Saving Image

# %%
cv2.imwrite('leena.jpg',img)
# Out:
# True

# %%
# Read Image
pp = cv2.imread('/content/peeper.jpg',0)


# Display Image
cv2_imshow(pp)

# Save Image
cv2.imwrite('pp.jpg',pp)
# Out:
# <PIL.Image.Image image mode=L size=223x222>
# True

# %%
cv2.rotate(pp,cv2.ROTATE_90_CLOCKWISE)
# Out:
# array([[209, 206, 199, ..., 193, 192, 216],
#        [111, 106, 101, ...,  14,  31, 181],
#        [128, 117, 119, ...,   8,   0, 218],
#        ...,
#        [198, 196, 192, ...,   1,  10, 209],
#        [200, 199, 197, ...,   1,  22, 188],
#        [194, 191, 192, ..., 225, 177, 219]], dtype=uint8)

# %%
cv2.resize(pp,(0,0),fx=0.20,fy=0.20)
# Out:
# array([[  8,   9,   1, ...,   6,   0, 225],
#        [ 80, 115, 132, ..., 160, 172, 215],
#        [174, 175, 179, ..., 143, 143, 207],
#        ...,
#        [175, 187, 180, ..., 110,  81, 212],
#        [ 84, 186, 190, ...,  94, 160, 208],
#        [128, 153, 190, ..., 156, 151, 208]], dtype=uint8)

# %%
pp
# Out:
# array([[216, 181, 218, ..., 209, 188, 219],
#        [192,  31,   0, ...,  10,  22, 177],
#        [193,  14,   8, ...,   1,   1, 225],
#        ...,
#        [199, 101, 119, ..., 192, 197, 192],
#        [206, 106, 117, ..., 196, 199, 191],
#        [209, 111, 128, ..., 198, 200, 194]], dtype=uint8)

# %%
# X ray Image

# %%
# Read Image
xr = cv2.imread('/content/xray.jpg',0)

# Display Image
cv2_imshow(xr)

# Save Image
cv2.imwrite('xr.jpg',xr)

# Resize
cv2.resize(xr,(0,0),fx=0.20,fy=0.20)
# Out:
# <PIL.Image.Image image mode=L size=248x203>
# array([[ 14,  14,  14, ...,  14,  17,  33],
#        [ 14,  14,  14, ...,  14,  17,  33],
#        [ 12,  12,  12, ...,  13,  11,  28],
#        ...,
#        [ 96, 119, 143, ...,  80,  39,  37],
#        [ 94, 117, 167, ...,  78,  37,  35],
#        [130, 153, 182, ..., 126,  86,  64]], dtype=uint8)

# %%
# Rotate
cv2.rotate(xr,cv2.ROTATE_90_CLOCKWISE)
# Out:
# array([[117, 101,  82, ...,  14,  14,  14],
#        [123, 107,  88, ...,  14,  14,  14],
#        [130, 114,  95, ...,  14,  14,  14],
#        ...,
#        [ 64,  48,  29, ...,  15,  15,  15],
#        [ 55,  38,  19, ...,  11,  11,  11],
#        [ 64,  48,  28, ...,  33,  33,  33]], dtype=uint8)
